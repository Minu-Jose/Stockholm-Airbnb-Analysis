# %%
import pandas as pd

df = pd.read_csv("../data/raw/listings.csv")
df.head()
# Out:
#        id                                         name  host_id host_name  \
# 0  164448  Double room in central Stockholm with Wi-Fi   784312        Li
# 1  220851                      One room in appartement   412283   Fredric
# 2  238411          Cozy apartment in central Stockholm  1250232       Mia
# 3  242188  Single room in central Stockholm with Wi-Fi   784312        Li
# 4  273906               Penthouse in central Stockholm  1432722   Rodrigo
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0                  NaN    Södermalms  59.31389   18.06087     Private room
# 1                  NaN  Kungsholmens  59.33351   18.03693     Private room
# 2                  NaN     Norrmalms  59.33872   18.05131  Entire home/apt
# 3                  NaN    Södermalms  59.31198   18.06076     Private room
# 4                  NaN    Södermalms  59.30543   18.10771  Entire home/apt
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4955 entries, 0 to 4954
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              4955 non-null   int64
#  1   name                            4955 non-null   str
#  2   host_id                         4955 non-null   int64
#  3   host_name                       4951 non-null   str
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   4955 non-null   str
#  6   latitude                        4955 non-null   float64
#  7   longitude                       4955 non-null   float64
#  8   room_type                       4955 non-null   str
#  9   price                           3190 non-null   float64
#  10  minimum_nights                  4955 non-null   int64
#  11  number_of_reviews               4955 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            4
# neighbourhood_group               4955
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                             1765
# minimum_nights                       0
# number_of_reviews                    0
# last_review                        869
# reviews_per_month                  869
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           4955
# dtype: int64

# %%
rows_before_cleaning=df.shape[0]
rows_before_cleaning
df = df.dropna(subset=["price"])
rows_after_cleaning = df.shape[0]
rows_after_cleaning


df.to_csv("../data/cleaned/cleaned_listings.csv", index=False)
df
# Out:
#                        id                                               name  \
# 0                  164448        Double room in central Stockholm with Wi-Fi
# 1                  220851                            One room in appartement
# 2                  238411                Cozy apartment in central Stockholm
# 3                  242188        Single room in central Stockholm with Wi-Fi
# 4                  273906                     Penthouse in central Stockholm
# ...                   ...                                                ...
# 4950  1518315388896689673           Ljus lägenhet med balkong - Abrahamsberg
# 4951  1518947120255495232           Furnished Room in the Heart of Stockholm
# 4952  1518992217482651420                                       Attefallshus
# 4953  1519642719140641464   Worker & Family Studio • 2 Beds + Fully equipped
# 4954  1519716586978462297  Beautiful and cozy room with new floor & new b...
#
# ...

# %% [markdown]
# ## Average Airbnb price in Stockhom

# %%
df["price"].mean()
# Out:
# np.float64(1690.4730407523512)

# %% [markdown]
# ## Price by room type

# %%
price_by_room_type=(
    df.groupby("room_type")["price"]
    .mean()
    .reset_index(name="average price")
)
price_by_room_type
# Out:
#          room_type  average price
# 0  Entire home/apt    1781.735433
# 1       Hotel room     303.000000
# 2     Private room    1374.236715
# 3      Shared room     474.892857

# %% [markdown]
# ## Most expensive neighbourhoods

# %%
price_by_neighbourhood =(
    df.groupby("neighbourhood")["price"]
    .mean()
    .sort_values(ascending=False)
    .round(2)
    .reset_index()
)
price_by_neighbourhood
# Out:
#              neighbourhood    price
# 0                Norrmalms  2643.11
# 1                   Bromma  2302.66
# 2               Östermalms  2002.16
# 3               Södermalms  1761.61
# 4                   Älvsjö  1647.37
# 5             Kungsholmens  1542.04
# 6                   Farsta  1532.74
# 7   Hägersten-Liljeholmens  1470.28
# 8       Hässelby-Vällingby  1358.87
# 9    Enskede-Årsta-Vantörs  1345.03
# 10              Skarpnäcks  1227.06
# 11           Spånga-Tensta  1025.21
# 12          Rinkeby-Tensta   840.76
# 13             Skärholmens   826.64

# %% [markdown]
# ## Listings Vs Reviews

# %%
df[["price","number_of_reviews"]].corr()
## Check
# Out:
#                       price  number_of_reviews
# price              1.000000          -0.039242
# number_of_reviews -0.039242           1.000000
